# %%
from bs4 import BeautifulSoup
import requests

# %%
url1 = 'https://www.kaggle.com/datasets/datafiniti/consumer-reviews-of-amazon-products'
page_1 = requests.get(url1)

# %%
soup_1 = BeautifulSoup(page_1.text, 'html')

# %%
print(soup_1)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <title>Consumer Reviews of Amazon Products | Kaggle</title>
# <meta charset="utf-8"/>
# <meta content="index, follow" name="robots"/>
# <meta content="A list of over 34,000 reviews of Amazon products like the Kindle, Fire TV, etc." name="description"/>
# <meta content="internet,retail and shopping,ratings and reviews" name="keywords"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0" name="viewport"/>
# <meta content="#008ABC" name="theme-color"/>
# <script nonce="g1Itmf/oBlxYV34/i6dpJA==" type="text/javascript">
#     window["pageRequestStartTime"] = 1717059047057;
#     window["pageRequestEndTime"] = 1717059047151;
#     window["initialPageLoadStartTime"] = new Date().getTime();
#   </script>
# <script async="" defer="" id="gsi-client" nonce="g1Itmf/oBlxYV34/i6dpJA==" src="https://accounts.google.com/gsi/client"></script>
# ...

# %%
url2 = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_States_by_revenue'
page_2 = requests.get(url2)

# %%
soup_2 = BeautifulSoup(page_2.text, 'html')

# %%
soup_2.find('table')
# Out:
# <table class="box-More_citations_needed plainlinks metadata ambox ambox-content ambox-Refimprove" role="presentation"><tbody><tr><td class="mbox-image"><div class="mbox-image-div"><span typeof="mw:File"><a class="mw-file-description" href="/wiki/File:Question_book-new.svg"><img alt="" class="mw-file-element" data-file-height="399" data-file-width="512" decoding="async" height="39" src="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/50px-Question_book-new.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/75px-Question_book-new.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/9/99/Question_book-new.svg/100px-Question_book-new.svg.png 2x" width="50"/></a></span></div></td><td class="mbox-text"><div class="mbox-text-span">This article <b>needs additional citations for <a href="/wiki/Wikipedia:Verifiability" title="Wikipedia:Verifiability">verification</a></b>.<span class="hide-when-compact"> Please help <a href="/wiki/Speci
# ...

# %%
table = soup_2.find_all('table')[1]

# %%
print(table)
# Out:
# <table class="wikitable sortable">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td><a href="/wiki/Retail" title="Retail">Retail</a>
# </td>
# <td style="text-align:center;">611,289
# </td>
# ...

# %%
world_titles = table.find_all('th')

# %%
print(world_titles)
# Out:
# [<th>Rank
# </th>, <th>Name
# </th>, <th>Industry
# </th>, <th>Revenue <br/>(USD millions)
# </th>, <th>Revenue growth
# </th>, <th>Employees
# </th>, <th>Headquarters
# </th>]

# %%
world_table_titles = [title.text.strip() for title in world_titles]

# %%
print(world_table_titles)
# Out:
# ['Rank', 'Name', 'Industry', 'Revenue (USD millions)', 'Revenue growth', 'Employees', 'Headquarters']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns = world_table_titles)
df
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Industry, Revenue (USD millions), Revenue growth, Employees, Headquarters]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
print(column_data)
# Out:
# [<tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Industry
# </th>
# <th>Revenue <br/>(USD millions)
# </th>
# <th>Revenue growth
# </th>
# <th>Employees
# </th>
# <th>Headquarters
# </th></tr>, <tr>
# <td>1
# </td>
# <td><a href="/wiki/Walmart" title="Walmart">Walmart</a>
# </td>
# <td><a href="/wiki/Retail" title="Retail">Retail</a>
# </td>
# <td style="text-align:center;">611,289
# </td>
# <td style="text-align:center;"><span typeof="mw:File"><span title="Increase"><img alt="Increase" class="mw-file-element" data-file-height="300" data-file-width="300" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/11px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/17px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/22px-Increase2.svg.png 2x" width="11"/></span></span> <span data-sort-value="7000300000000000000♠" style="display:none"></span> 6.7%
# </td>
# ...

# %%
for values in column_data[1:]:
    row_data = values.find_all('td')
    individual_data = [data.text.strip() for data in row_data]
    
    length = len(df)
    df.loc[length] = individual_data

# %%
df
# Out:
#    Rank                      Name                    Industry  \
# 0     1                   Walmart                      Retail
# 1     2                    Amazon  Retail and cloud computing
# 2     3                ExxonMobil          Petroleum industry
# 3     4                     Apple        Electronics industry
# 4     5        UnitedHealth Group                  Healthcare
# ..  ...                       ...                         ...
# 95   96                  Best Buy                      Retail
# 96   97      Bristol-Myers Squibb     Pharmaceutical industry
# 97   98           United Airlines                     Airline
# 98   99  Thermo Fisher Scientific      Laboratory instruments
# 99  100                  Qualcomm                  Technology
#
#    Revenue (USD millions) Revenue growth  Employees             Headquarters
# 0                 611,289           6.7%  2,100,000    Bentonville, Arkansas
# ...

# %%
df.to_csv(r'C:\Users\pro\Desktop\My Materials\GRT\Web Scrape\US_companies_highest_revenue.csv', index = False)

# %%
with open('C:/Users/pro/Downloads/Outlier (5_24_2024 6_17_59 PM).html', 'r', encoding='utf-8') as file:
    html_content = file.read()

# %%
print(html_content)
# Out:
# <!DOCTYPE html> <html lang=en translate=no style><!--
#  Page saved with SingleFile
#  url: https://app.outlier.ai/en/expert/tasks
#  saved date: Fri May 24 2024 18:17:59 GMT+0530 (India Standard Time)
# ...

# %%
soup_3 = BeautifulSoup(html_content, 'html.parser')

# %%
soup_3.find('div', class_ ='space-y-1')
# Out:
# <div class="space-y-1"><textarea class="block w-full rounded-md py-2 text-neutral-900 sm:text-sm shadow-sm border-1 placeholder:text-neutral-400 transition outline-none bg-neutral-0 min-h-[38px] focus:border-primary-400 focus:ring-primary-400 border-neutral-300" name="Tool_Capability_Edge_Case *-0" rows="4">NONE</textarea></div>

# %%
justification = soup_3.find_all('textarea')[2]
print(justification)
# Out:
# <textarea class="block w-full rounded-md py-2 text-neutral-900 sm:text-sm shadow-sm border-1 placeholder:text-neutral-400 transition outline-none bg-neutral-0 min-h-[38px] focus:border-primary-400 focus:ring-primary-400 border-neutral-300" name="Explain how you chose this final comparison rating. Your justification should have a declaration in the beginning stating why one response is better than the other (or if they are the same) and an evidence-based reason for your decision that cites information directly from the prompts and responses.  Additionally, include clear evidence for every rating (Tool Name Correctness, Function Correctness, Function Parameter Correctness and Fulfillment) without fail.  If you provide a generic justification, your task will be rejected. *-0" rows="4">Response 1 and Response 2 are similar and of equal quality because both responses used the same tool, function, and parameters and completely fulfilled the user requirement by providing all the destination
# ...

# %%
print(type(justification))
# Out:
# <class 'bs4.element.Tag'>

# %%
url3 = 'https://app.outlier.ai/expert/feedback'
page3=requests.get(url3)

# %%
soup4 = BeautifulSoup(page3.text,'html')

# %%
print(soup4)
# Out:
# <!DOCTYPE html>
# ...
